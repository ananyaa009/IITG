# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.float_format', lambda x: f'{x: .2f}')

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\aryas\Downloads\Cars.csv")
print(df.head())
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.00          8        307.00      130.00    3504         12.00
# 1  15.00          8        350.00      165.00    3693         11.50
# 2  18.00          8        318.00      150.00    3436         11.00
# 3  16.00          8        304.00      150.00    3433         12.00
# 4  17.00          8        302.00      140.00    3449         10.50
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
df.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
print(df.columns)
column_names = np.array(df.columns)
print(column_names)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')
# ['mpg' 'cylinders' 'displacement' 'horsepower' 'weight' 'acceleration'
#  'model_year' 'origin' 'name']

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
print(df.columns.tolist())
df.set_index('name', inplace=True)
# Out:
# ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'name']

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
unique_mpg_values = df['mpg'].unique()
print(unique_mpg_values.tolist())
# Out:
# [18.0, 15.0, 16.0, 17.0, 14.0, 24.0, 22.0, 21.0, 27.0, 26.0, 25.0, 10.0, 11.0, 9.0, 28.0, 19.0, 12.0, 13.0, 23.0, 30.0, 31.0, 35.0, 20.0, 29.0, 32.0, 33.0, 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5, 26.5, 16.5, 31.5, 36.0, 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1, 32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1, 17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2, 19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2, 34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4, 24.3, 19.1, 34.3, 29.8, 31.3, 37.0, 32.2, 46.6, 27.9, 40.8, 44.3, 43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8, 23.5, 39.1, 39.0, 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9, 31.6, 28.1, 30.7, 24.2, 22.4, 34.0, 38.0, 44.0]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
df['hp_per_weight'] = df['horsepower'] / df['weight']
df.set_index('hp_per_weight', inplace=True)
print(df.head())
# Out:
#                  mpg  cylinders  displacement  horsepower  weight  \
# hp_per_weight
# 0.04           18.00          8        307.00      130.00    3504
# 0.04           15.00          8        350.00      165.00    3693
# 0.04           18.00          8        318.00      150.00    3436
# 0.04           16.00          8        304.00      150.00    3433
# 0.04           17.00          8        302.00      140.00    3449
#
#                acceleration  model_year origin
# hp_per_weight
# 0.04                  12.00          70    usa
# 0.04                  11.50          70    usa
# 0.04                  11.00          70    usa
# 0.04                  12.00          70    usa
# 0.04                  10.50          70    usa

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
max_hp = df.loc[df['horsepower'].idxmax()]
car_name = max_hp['name']
print('Car with highest horsepower:', car_name)
# Out:
# Car with highest horsepower: pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
num_cars_high_mpg = df[df['mpg'] >= 35].shape[0]
print("Number of cars with mpg >= 35:", num_cars_high_mpg)
# Out:
# Number of cars with mpg >= 35: 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
origin_cars = df[(df['horsepower'] > 100) & (df['weight'] < 3000)]
most_common_origin = origin_cars['origin'].mode()[0]
print('Most common origin:', most_common_origin)
# Out:
# Most common origin: usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
mean_acc_japan = df[df['origin'] == 'japan']['acceleration'].mean()
print("Mean acceleraton of cars from Japan:", round(mean_acc_japan, 2))
# Out:
# Mean acceleraton of cars from Japan: 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
highest_avg_mpg = df.groupby('model_year')['mpg'].mean().idxmax()
print("Year with highest average MPG:", highest_avg_mpg)
# Out:
# Year with highest average MPG: 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
median_mpg = df['mpg'].median()
above_median_mpg_cars = df[df['mpg'] > median_mpg].copy()
above_median_mpg_cars['hp_to_weight'] = above_median_mpg_cars['horsepower'] / above_median_mpg_cars['weight']
ratio = above_median_mpg_cars['hp_to_weight'].max()
best_cars = above_median_mpg_cars[above_median_mpg_cars['hp_to_weight'] == ratio]
print(best_cars[['name', 'horsepower', 'weight', 'mpg', 'hp_to_weight']])
# Out:
#         name  horsepower  weight    mpg  hp_to_weight
# 23  bmw 2002      113.00    2234  26.00          0.05

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
avg_mpg_over_year = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data = avg_mpg_over_year, x = 'model_year', y = 'mpg', hue = 'origin', marker = 'o' )
plt.title('Evolution of Average MPG Over Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
plt.figure(figsize=(10,6))
scatter = sns.scatterplot(
    data = df,x = 'horsepower',y = 'weight',hue = 'origin',size = 'mpg',
    sizes = (20, 200),hue_order=['japan','europe','usa'],palette='Set2',alpha = 0.7,edgecolor = 'w'
)
plt.title('Scatterplot of horsepower vs weight \ ncolored by origin and sized by MPG') 
plt.xlabel('horsepower')
plt.ylabel('weight')
plt.legend(title = 'origin', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
car_counts = df.groupby('name')['model_year'].nunique()
multi_year_cars = car_counts[car_counts >= 2].index
mpg_stats = df[df['name'].isin(multi_year_cars)].groupby('name')['mpg'].agg(['std','mean','count'])
consistent_cars = mpg_stats[mpg_stats['std'] < 1.0]
lowest_std  = consistent_cars['std'].min()
best_consistent_cars = consistent_cars[consistent_cars['std'] == lowest_std]
best_consistent_cars_sorted = best_consistent_cars.sort_values(by=['count','mean'], ascending=[False, False])
result = best_consistent_cars_sorted[['count','mean']]
result.rename(columns={'count': 'number_of_appearances', 'mean': 'average_mpg'}, inplace = True)
print(result)
# Out:
#               number_of_appearances  average_mpg
# name
# datsun pl510                      2        27.00

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
